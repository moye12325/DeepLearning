# %%
import os
import torch
import torchvision
from torch import nn
from d2l import torch as d2l
# Out:
# Requirement already satisfied: d2l in c:\users\19423\.conda\envs\nlp\lib\site-packages (0.17.5)
# Requirement already satisfied: requests==2.25.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from d2l) (2.25.1)
# Requirement already satisfied: numpy==1.21.5 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from d2l) (1.21.5)
# Requirement already satisfied: jupyter==1.0.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from d2l) (1.0.0)
# Requirement already satisfied: matplotlib==3.5.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from d2l) (3.5.1)
# Requirement already satisfied: pandas==1.2.4 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from d2l) (1.2.4)
# Requirement already satisfied: qtconsole in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter==1.0.0->d2l) (5.3.0)
# Requirement already satisfied: ipykernel in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter==1.0.0->d2l) (6.13.0)
# Requirement already satisfied: notebook in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter==1.0.0->d2l) (6.4.11)
# Requirement already satisfied: ipywidgets in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter==1.0.0->d2l) (7.7.0)
# Requirement already satisfied: jupyter-console in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter==1.0.0->d2l) (6.4.3)
# Requirement already satisfied: nbconvert in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter==1.0.0->d2l) (6.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from matplotlib==3.5.1->d2l) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from pandas==1.2.4->d2l) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from requests==2.25.1->d2l) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from requests==2.25.1->d2l) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from requests==2.25.1->d2l) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from requests==2.25.1->d2l) (1.26.9)
# Requirement already satisfied: six>=1.5 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.5.1->d2l) (1.16.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.6.0)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.2.2.post1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (7.3.1)
# Requirement already satisfied: nest-asyncio in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.1.3)
# Requirement already satisfied: psutil in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.9.1)
# Requirement already satisfied: backcall in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: colorama in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.12.0)
# Requirement already satisfied: stack-data in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.18.1)
# Requirement already satisfied: decorator in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (61.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.3)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: entrypoints in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0->d2l) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0->d2l) (4.10.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->jupyter==1.0.0->d2l) (304)
# Requirement already satisfied: wcwidth in c:\users\19423\.conda\envs\nlp\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l) (1.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->d2l) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->d2l) (4.6.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->d2l) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter==1.0.0->d2l) (21.4.0)
# Requirement already satisfied: jinja2 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (3.1.2)
# Requirement already satisfied: argon2-cffi in c:\users\19423\.conda\envs\nlp\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\19423\.conda\envs\nlp\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from notebook->jupyter==1.0.0->d2l) (0.15.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.11.1)
# Requirement already satisfied: bleach in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (2.1.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: tinycss2 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.6.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.8.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0->d2l) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\19423\.conda\envs\nlp\lib\site-packages (from argon2-cffi->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0->d2l) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\19423\.conda\envs\nlp\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0->d2l) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\19423\.conda\envs\nlp\lib\site-packages (from bleach->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\19423\.conda\envs\nlp\lib\site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.1.0)
# Requirement already satisfied: asttokens in c:\users\19423\.conda\envs\nlp\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\19423\.conda\envs\nlp\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: executing in c:\users\19423\.conda\envs\nlp\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.3)

# %%
#@save
d2l.DATA_HUB['dog_tiny'] = (d2l.DATA_URL + 'kaggle_dog_tiny.zip',
                            '0cb91d09b814ecdc07b50f31f8dcad3e81d6a86d')

# 如果你使用Kaggle比赛的完整数据集，请将下面的变量更改为False
demo = False
if demo:
    data_dir = d2l.download_extract('dog_tiny')
else:
    data_dir = os.path.join('..', 'input', 'dogbreed')
print(data_dir)
# ../input/dogbreed
# Out:
# Downloading ..\data\kaggle_dog_tiny.zip from http://d2l-data.s3-accelerate.amazonaws.com/kaggle_dog_tiny.zip...
# ..\data\kaggle_dog_tiny

# %%
def reorg_dog_data(data_dir, valid_ratio):
    labels = d2l.read_csv_labels(os.path.join(data_dir, 'labels.csv'))
    d2l.reorg_train_valid(data_dir, labels, valid_ratio)
    d2l.reorg_test(data_dir)


batch_size = 32 if demo else 128
valid_ratio = 0.1
reorg_dog_data(data_dir, valid_ratio)

# %%
transform_train = torchvision.transforms.Compose([
    # 随机裁剪图像，所得图像为原始面积的0.08到1之间，高宽比在3/4和4/3之间。
    # 然后，缩放图像以创建224x224的新图像
    torchvision.transforms.RandomResizedCrop(224, scale=(0.08, 1.0),
                                             ratio=(3.0/4.0, 4.0/3.0)),
    torchvision.transforms.RandomHorizontalFlip(),
    # 随机更改亮度，对比度和饱和度
    torchvision.transforms.ColorJitter(brightness=0.4,
                                       contrast=0.4,
                                       saturation=0.4),
    # 添加随机噪声
    torchvision.transforms.ToTensor(),
    # 标准化图像的每个通道
    torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])])

# %%
transform_test = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    # 从图像中心裁切224x224大小的图片
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])])

# %%
train_ds, train_valid_ds = [torchvision.datasets.ImageFolder(
    os.path.join(data_dir, 'train_valid_test', folder),
    transform=transform_train) for folder in ['train', 'train_valid']]

valid_ds, test_ds = [torchvision.datasets.ImageFolder(
    os.path.join(data_dir, 'train_valid_test', folder),
    transform=transform_test) for folder in ['valid', 'test']]

# %%
train_iter, train_valid_iter = [torch.utils.data.DataLoader(
    dataset, batch_size, shuffle=True, drop_last=True)
    for dataset in (train_ds, train_valid_ds)]

valid_iter = torch.utils.data.DataLoader(valid_ds, batch_size, shuffle=False,
                                         drop_last=True)

test_iter = torch.utils.data.DataLoader(test_ds, batch_size, shuffle=False,
                                        drop_last=False)

# %%
def get_net(devices):
    finetune_net = nn.Sequential()
    finetune_net.features = torchvision.models.resnet34(pretrained=True)
    # 定义一个新的输出网络，共有120个输出类别
    finetune_net.output_new = nn.Sequential(nn.Linear(1000, 256),
                                            nn.ReLU(),
                                            nn.Linear(256, 120))
    # 将模型参数分配给用于计算的CPU或GPU
    finetune_net = finetune_net.to(devices[0])
    # 冻结参数
    for param in finetune_net.features.parameters():
        param.requires_grad = False
    return finetune_net

# %%
loss = nn.CrossEntropyLoss(reduction='none')

def evaluate_loss(data_iter, net, devices):
    l_sum, n = 0.0, 0
    for features, labels in data_iter:
        features, labels = features.to(devices[0]), labels.to(devices[0])
        outputs = net(features)
        l = loss(outputs, labels)
        l_sum += l.sum()
        n += labels.numel()
    return (l_sum / n).to('cpu')

# %%
def train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
          lr_decay):
    # 只训练小型自定义输出网络
    net = nn.DataParallel(net, device_ids=devices).to(devices[0])
    trainer = torch.optim.SGD((param for param in net.parameters()
                               if param.requires_grad), lr=lr,
                              momentum=0.9, weight_decay=wd)
    scheduler = torch.optim.lr_scheduler.StepLR(trainer, lr_period, lr_decay)
    num_batches, timer = len(train_iter), d2l.Timer()
    legend = ['train loss']
    if valid_iter is not None:
        legend.append('valid loss')
    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
                            legend=legend)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(2)
        for i, (features, labels) in enumerate(train_iter):
            timer.start()
            features, labels = features.to(devices[0]), labels.to(devices[0])
            trainer.zero_grad()
            output = net(features)
            l = loss(output, labels).sum()
            l.backward()
            trainer.step()
            metric.add(l, labels.shape[0])
            timer.stop()
            if (i + 1) % (num_batches // 5) == 0 or i == num_batches - 1:
                animator.add(epoch + (i + 1) / num_batches,
                             (metric[0] / metric[1], None))
        measures = f'train loss {metric[0] / metric[1]:.3f}'
        if valid_iter is not None:
            valid_loss = evaluate_loss(valid_iter, net, devices)
            animator.add(epoch + 1, (None, valid_loss.detach().cpu()))
        scheduler.step()
    if valid_iter is not None:
        measures += f', valid loss {valid_loss:.3f}'
    print(measures + f'\n{metric[1] * num_epochs / timer.sum():.1f}'
          f' examples/sec on {str(devices)}')

# %%
devices, num_epochs, lr, wd = d2l.try_all_gpus(), 10, 1e-4, 1e-4
lr_period, lr_decay, net = 2, 0.9, get_net(devices)
train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
      lr_decay)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 devices, num_epochs, lr, wd = d2l.try_all_gpus(), 10, 1e-4, 1e-4
#       2 lr_period, lr_decay, net = 2, 0.9, get_net(devices)
# ----> 3 train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period,
#       4       lr_decay)
#
# Input In [13], in train(net, train_iter, valid_iter, num_epochs, lr, wd, devices, lr_period, lr_decay)
#      15 for epoch in range(num_epochs):
#      16     metric = d2l.Accumulator(2)
# ---> 17     for i, (features, labels) in enumerate(train_iter):
#      18         timer.start()
#      19         features, labels = features.to(devices[0]), labels.to(devices[0])
#
# File ~\.conda\envs\nlp\lib\site-packages\torch\utils\data\dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\.conda\envs\nlp\lib\site-packages\torch\utils\data\dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     568 def _next_data(self):
#     569     index = self._next_index()  # may raise StopIteration
# --> 570     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571     if self._pin_memory:
#     572         data = _utils.pin_memory.pin_memory(data)
#
# File ~\.conda\envs\nlp\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~\.conda\envs\nlp\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~\.conda\envs\nlp\lib\site-packages\torchvision\datasets\folder.py:230, in DatasetFolder.__getitem__(self, index)
#     222 """
#     223 Args:
#     224     index (int): Index
#    (...)
#     227     tuple: (sample, target) where target is class_index of the target class.
#     228 """
#     229 path, target = self.samples[index]
# --> 230 sample = self.loader(path)
#     231 if self.transform is not None:
#     232     sample = self.transform(sample)
#
# File ~\.conda\envs\nlp\lib\site-packages\torchvision\datasets\folder.py:269, in default_loader(path)
#     267     return accimage_loader(path)
#     268 else:
# --> 269     return pil_loader(path)
#
# File ~\.conda\envs\nlp\lib\site-packages\torchvision\datasets\folder.py:249, in pil_loader(path)
#     247 with open(path, "rb") as f:
#     248     img = Image.open(f)
# --> 249     return img.convert("RGB")
#
# File ~\.conda\envs\nlp\lib\site-packages\PIL\Image.py:889, in Image.convert(self, mode, matrix, dither, palette, colors)
#     847 def convert(self, mode=None, matrix=None, dither=None, palette=WEB, colors=256):
#     848     """
#     849     Returns a converted copy of this image. For the "P" mode, this
#     850     method translates pixels through the palette.  If mode is
#    (...)
#     886     :returns: An :py:class:`~PIL.Image.Image` object.
#     887     """
# --> 889     self.load()
#     891     has_transparency = self.info.get("transparency") is not None
#     892     if not mode and self.mode == "P":
#     893         # determine default mode
#
# File ~\.conda\envs\nlp\lib\site-packages\PIL\ImageFile.py:235, in ImageFile.load(self)
#     233 while True:
#     234     try:
# --> 235         s = read(self.decodermaxblock)
#     236     except (IndexError, struct.error) as e:
#     237         # truncated png/gif
#     238         if LOAD_TRUNCATED_IMAGES:
#
# File ~\.conda\envs\nlp\lib\site-packages\PIL\JpegImagePlugin.py:402, in JpegImageFile.load_read(self, read_bytes)
#     396 def load_read(self, read_bytes):
#     397     """
#     398     internal: read more image data
#     399     For premature EOF and LOAD_TRUNCATED_IMAGES adds EOI marker
#     400     so libjpeg can finish decoding
#     401     """
# --> 402     s = self.fp.read(read_bytes)
#     404     if not s and ImageFile.LOAD_TRUNCATED_IMAGES and not hasattr(self, "_ended"):
#     405         # Premature EOF.
#     406         # Pretend file is finished adding EOI marker
#     407         self._ended = True
#
# KeyboardInterrupt:

# %%
net = get_net(devices)
train(net, train_valid_iter, None, num_epochs, lr, wd, devices, lr_period,
      lr_decay)

preds = []
for data, label in test_iter:
    output = torch.nn.functional.softmax(net(data.to(devices[0])), dim=0)
    preds.extend(output.cpu().detach().numpy())
ids = sorted(os.listdir(
    os.path.join(data_dir, 'train_valid_test', 'test', 'unknown')))
with open('submission.csv', 'w') as f:
    f.write('id,' + ','.join(train_valid_ds.classes) + '\n')
    for i, output in zip(ids, preds):
        f.write(i.split('.')[0] + ',' + ','.join(
            [str(num) for num in output]) + '\n')
